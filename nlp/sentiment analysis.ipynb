# %%
import pandas as pd

df = pd.read_csv('post1.csv', encoding='utf-8')

# %%
# Check the number of posts
print("The number of posts:", len(df['Post']))

# Check the number of posts with null values
print("The number of posts with null:", df['Post'].isnull().sum())

# Drop rows with null values in the 'Post' or 'PostId' columns
df = df.dropna(subset=['Post', 'PostId'])

# Remove duplicate rows based on the 'PostId' column
df = df.drop_duplicates(subset=['PostId'])

# Check the number of posts after removing nulls and duplicates
print("The number of posts after removing nulls and duplicates:", len(df['Post']))

# Display the first few rows of the DataFrame
df.head()
# Out:
# The number of posts: 600
# The number of posts with null: 114
# The number of posts after removing nulls and duplicates: 486
#                                               PostId  \
# 0  https://m.facebook.com/story.php?story_fbid=pf...
# 1  https://m.facebook.com/story.php?story_fbid=pf...
# 2  https://m.facebook.com/story.php?story_fbid=pf...
# 3  https://m.facebook.com/story.php?story_fbid=pf...
# 4  https://m.facebook.com/story.php?story_fbid=pf...
#
#                                                 Post  \
# 0  Go out and don't forget to participate 😉💸😍 · R...
# 1  Win big with TT and Gem FM & TV 🥳🥳  Cambodian ...
# 2          Fresh ya winner 💪 · Rate this translation
# 3  With a new service Ehdia Pass Roaming Data, I ...
# 4  Who is the famous personality who uses her voi...
#
#                                             Comments                  Time
# 0  [['Sleh Khmassi ', 'Game of word for you', '/s...                  1 hr
# ...

# %%
from textblob import TextBlob
import pandas as pd

# Load the dataset
# Initialize the TextBlob sentiment analyzer
threshold = 0.0

# Create empty lists to store the sentiment scores and labels
polarity_scores = []
subjectivity_scores = []
true_labels = []

# Iterate over the text data in the dataset and predict the sentiment score for each comment
comments = df['Comments']  # Get the list of comments
for comment in comments:
    comment_list = eval(comment)
    if len(comment_list) >= 2:
        for p in comment_list:
            text = p[1]
            blob = TextBlob(text)

            # Get the polarity score (ranges from -1 to 1)
            polarity_score = blob.sentiment.polarity
            polarity_scores.append(polarity_score)
            
            # Get the subjectivity score (ranges from 0 to 1)
            subjectivity_scores.append(blob.sentiment.subjectivity)

            # Determine the sentiment label based on the polarity score
            if polarity_score >= 0.1:
                label = "positive"
            elif polarity_score <= -0.3:
                label = "negative"
            else:
                label = "neutral"

            # Add the label to the comment array
            p.append(label)
            # Add the label to the labels list
            true_labels.append(label)
    # Add the modified comment back to the list of comments

# %%
negative_words = ['always cut', 'slow internet', 'frustrating','connection problem',"Terrible service","don't have", "Poor network coverage", "Slow internet speed", "Frequent disconnections", "Dropped calls", "Poor customer service", "Billing errors",'waiting ', "Hidden fees", "Unreliable service", "No signal", "Noisy line", "Poor call quality", "Outage", "Delayed repairs", "Unresponsive technical support", "Lack of information", "Incompetent staff", "Rude staff", "Unprofessional behavior", "Poor communication", "Incorrect charges", "Unauthorized charges", "Inconsistent service", "Service outage", "Frequent interruptions", "Long wait times", "Missed appointments", "Unresolved issues", "Inadequate compensation", "Poor equipment", "Outdated equipment", "Overpriced plans", "Limited data usage", "Unfair contracts", "Misleading advertising", "Poor value for money", "Lack of transparency", "Unreasonable policies", "Poor coverage", "Slow response times", "No email support", "Limited hours of operation", "Lack of accountability", "Difficulty canceling service", "Poor reception", "Poor call routing", "Poor call center performance", "Inadequate training", "Ignored complaints", "Lack of empathy", "Unresolved disputes", "Non-functioning equipment", "Inefficient service", "Unreliable equipment", "Lack of availability", "Uninformed staff", "Poor website design", "Poor online support", "Inadequate service options", "Unreasonable fees", "Poor refund policy", "Poor customer experience", "Unresponsive customer service", "Poor billing practices", "Inadequate notification", "Delayed responses", "Difficulty speaking with a supervisor", "Unacceptable service", "Unnecessary fees", "Billing disputes", "Poor security", "Unauthorized changes to account", "Inadequate security measures", "No mobile network", "Poor mobile data speeds", "Slow mobile network", "Inconsistent mobile service", "Poor mobile coverage", "Poor mobile network performance", "Limited mobile data plans", "Unreliable mobile network", "Difficulty switching providers", "Poor phone reception", "Frequent dropped calls", "No voicemail", "Poor voicemail quality", "Unreliable voicemail", "Inconsistent voicemail service", "Poor text messaging service", "Delayed text messages", "Difficulty sending text messages", "Unreliable text messaging", "Limited text messaging options", "Unresponsive text messaging support", "No visual voicemail", "Unreliable visual voicemail", "Inconsistent visual voicemail service", "Poor video calling quality", "Frequent video call disconnections", "Limited video calling options", "Unreliable video calling service", "Inconsistent video calling performance", "Difficulty using mobile hotspot", "Limited mobile hotspot data", "Unreliable mobile hotspot service", "Poor mobile hotspot speeds", "Inconsistent mobile hotspot performance", "Difficulty accessing account information", "Unreliable account information", "Poor account security", "Poor website functionality", "Inconsistent website performance", "Difficulty using online features", "Poor online security", "Unauthorized access to account", "No call waiting", "Poor call waiting service", "Inconsistent call waiting performance", "Unreliable call waiting", "No caller ID", "Poor caller ID service", "Unreliable caller ID", "Inconsistent caller ID performance", "Difficulty using voicemail to text", "Poor voicemail to text service", "Unreliable voicemail to text", "Inconsistent voicemail to text performance", "Limited international calling options", "Unreliable international calling service","slow", "unreliable", "disconnected", "spotty", "interrupted", "frequent outages", "downtime", "not working", "not connecting", "can't access", "no signal", "weak signal", "poor signal", "signal problems", "weak connection", "poor connection", "connection problems", "network issues", "network problems", "unstable connection", "inconsistent connection", "interference", "noise", "static", "low bandwidth", "limited bandwidth", "not enough bandwidth", "bandwidth issues", "slow download speed", "slow upload speed", "slow internet", "lagging", "buffering", "constant buffering", "video not loading", "videos won't play", "slow streaming", "poor quality streaming", "streaming problems", "poor video quality", "video freezes", "audio drops out", "latency issues", "high latency", "slow web browsing", "slow page loads", "unable to access certain sites", "blocked sites", "restricted access", "no internet", "internet outage", "internet problems", "modem issues", "router problems", "equipment malfunction", "equipment failure", "hardware issues", "software issues", "compatibility issues", "configuration problems", "service interruptions", "billing errors", "overcharges", "hidden fees", "poor customer service", "unhelpful support", "unresponsive support", "long wait times", "unclear instructions", "complex instructions", "confusing website", "poor website design", "unreliable website", "dysfunctional website", "app not working", "app crashes", "app problems", "poor mobile signal", "poor Wi-Fi signal", "Wi-Fi not working", "slow Wi-Fi", "Wi-Fi outage", "router not working", "modem not working", "device compatibility issues", "internet speed not as advertised", "discrepancy between advertised speed and actual speed", "service not delivered as promised", "unfulfilled promises", "poor value", "not worth the price", "unreasonable fees", "unjustified charges", "poor reliability", "lack of reliability", "lack of accountability", "poor communication", "lack of communication", "poor transparency", "lack of transparency", "unclear terms and conditions", "hidden terms and conditions", "unfair terms and conditions", "poor service quality", "inadequate service quality", "poor network coverage", "inadequate network coverage", "poor call quality", "dropped calls", "call interference", "poor voice quality", "poor data quality", "poor text message quality", "text message problems", "SMS not working", "MMS not working", "missing messages", "late messages", "unsent messages", "undelivered messages", "message errors", "message delivery failures", "spam messages", "unwanted messages", "unsolicited messages", "privacy violations", "data breaches", "security issues", "insecure network", "unsecured network", "unencrypted data", "data theft", "identity theft", "fraudulent charges", "unauthorized charges", "unauthorized access", "unsolicited marketing calls", "telemarketing harassment", "robocalls", "spam calls", "phishing scams", "scam calls", "fraudulent calls", "missed appointments", "service cancellations","bad","how does it word","slow internet", "frequent disconnections", "poor connectivity", "intermittent service", "constant buffering", "low bandwidth", "inconsistent speed", "network congestion", "router problems", "modem issues", "poor signal strength", "outdated equipment", "expensive plans", "hidden fees", "poor customer service", "long wait times", "rude representatives", "unhelpful support", "unresolved issues", "billing errors", "account problems", "inaccurate charges", "overcharging", "unauthorized charges", "confusing bills", "lack of transparency", "data caps", "throttling", "blocked websites", "censorship", "privacy concerns", "security issues", "hacked accounts", "identity theft", "poor website performance", "slow loading times", "broken links", "server errors", "website downtime", "inaccessible websites", "poor mobile app", "frequent crashes", "unreliable app", "unintuitive interface", "poor design", "lack of features", "limited functionality", "poor integration", "incompatible devices", "poorly optimized", "overpriced plans", "uncompetitive pricing", "lack of promotional offers", "poor value for money", "limited availability", "no service in certain areas", "service blackouts", "long installation times", "missed appointments", "poor quality installations", "hidden installation fees", "unsatisfactory installation experience", "unsatisfactory customer experience", "unresponsive customer service", "lack of communication", "no follow-up", "disorganized support", "poor technical support", "untrained technicians", "poorly trained staff", "inadequate solutions", "repetitive troubleshooting", "lack of escalation", "poorly managed complaints", "no accountability", "unsatisfactory resolution", "poor dispute resolution", "unfair policies", "difficult cancellation process", "unjustified cancellation fees", "unreliable service", "unstable connection", "unexplained outages", "unannounced maintenance", "unscheduled downtime", "poor network coverage", "no 4G/LTE service", "slow 4G/LTE speeds", "poor 5G coverage", "no 5G service", "inadequate 5G speeds", "unreliable 5G connection", "inadequate fiber coverage", "no fiber service", "slow fiber speeds", "poor VoIP quality", "dropped calls", "poor call quality", "overlapping frequencies", "noisy phone line", "poor audio quality", "poor video quality", "unsatisfactory user experience", "outdated technology", "limited choice", "poor channel selection", "unavailable channels", "poor signal reception", "poor picture quality", "fuzzy reception", "unavailable on-demand content", "unreliable DVR", "poor streaming quality", "unavailable streaming content", "inadequate streaming speeds", "unreliable streaming connection", "poor IPTV quality", "inadequate bandwidth", "overloaded servers", "poor multicast performance", "poor quality of service", "lack of innovation", "poor investment in infrastructure", "inadequate research and development", "poor community engagement", "inadequate support for local initiatives", "poor corporate social responsibility", "unethical business practices","modem",'problem', 'issue', 'complaint','unjust','cut off','I regretted it','waste ',"didn't find it",'issues ','loss','nothing changed','less', 'defective','reclamation ','stealing','talk to us in private','private','faulty', 'error', 'mistake', 'broken', 'damaged', 'unsatisfactory','never works','not been announced']

# %%
import pandas as pd
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import f1_score
import string
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
import re

# Load the text data into a pandas dataframe

def preprocess_text(text):
    # Convert all text to lowercase
    text = text.lower()
    
    # Remove numbers and special characters
    text = re.sub(r'\d+', '', text)
    text = re.sub('wafi ', 'wifi ', text)
    text = re.sub('ena ', 'i ', text)
    text = re.sub('kivach ', 'how ', text)
    text = re.sub('top nat ', 'topnet ', text)
    text = re.sub("bon d'achat ", 'shopping voucher ', text)
    text = re.sub('bon d achat ', 'shopping voucher ', text)
    text = re.sub('my tt ', 'mytt ', text)
    text = re.sub('tt ', 'tunisie telecome ', text)
    
    text = text.translate(str.maketrans('', '', string.punctuation))
    
    # Tokenize the text
    tokens = text.split()
    
    # Remove stop words
    stop_words = set(stopwords.words('english'))
    tokens = [word for word in tokens if not word in stop_words]
    
    
    
    # Convert the list of tokens back to a string
    text = ' '.join(tokens)
    
    return text

# Apply the clean_text function to the Comments column
# Instantiate the VADER sentiment analyzer
analyzer = SentimentIntensityAnalyzer()
text = preprocess_text(text)
new_words = {
            'improve': 0.7,
            'connect': 0.7,
            'cut': -0.7,
            'waiting': -0.7
    
            }

# Update VADER's lexicon with the new words and scores
analyzer.lexicon.update(new_words)
threshold = 0.0

# Create empty lists to store the predicted sentiment scores and labels
pos_scores = []
neg_scores = []
neu_scores = []
compound_scores = []
Predicted_labels = []

# Iterate over the text data in the dataset and predict the sentiment score and label for each text
comments = df['Comments']  # Get the list of comments
for comment in comments:
    comment_list = eval(comment)
    if len(comment_list) >= 2:
        for p in comment_list:
            text = p[1]
            text = preprocess_text(text)
            score = analyzer.polarity_scores(text)
            pos_scores.append(score["pos"])
            neg_scores.append(score["neg"])
            neu_scores.append(score["neu"])
            compound_scores.append(score["compound"])
            if any(word in text for word in negative_words):
                label = "negative"
            elif score["compound"] >= 0.1:
                label = "positive"
            elif score["compound"] <= -0.3:
                label = "negative"
            else:
                label = "neutral"

            # Add the label to the comment array
            p.append(label)
            Predicted_labels.append(label)
            print(text)
            print(label)
            
    df.loc[df['Comments'] == comment, 'Comments'] = str(comment_list)

# Calculate the overall accuracy of the VADER model
accuracy = accuracy_score(true_labels, Predicted_labels)
report = classification_report(true_labels, Predicted_labels)

print(report)
from sklearn.metrics import precision_score

precision = precision_score(true_labels, Predicted_labels, pos_label='positive')
f1 = f1_score(true_labels, Predicted_labels, average='weighted')
print(f'precision: {precision:.3f}')
print(f'Accuracy: {accuracy:.3f}')
print(f'F1 score: {f1:.3f}')
df.to_csv("data_with_scores.csv", index=False)
# Out:
# game word
# neutral
#
# neutral
# game word
# neutral
# game word
# neutral
# game word
# neutral
# game word
# neutral
# game word
# neutral
# canbuzy
# neutral
# word
# neutral
# dont know
# neutral
# turn wheel
# neutral
# graphic creation tunisia telecom eyai contest😉✔️
# positive
# game word
# neutral
# game word
# neutral
# kitten credit 🤣🤣
# positive
# good morning
# positive
# good morning
# positive
# used participate every day prepare scori dima bahi called participated radio name appears bash play find sasi call
# positive
# hello
# neutral
# good morning
# positive
# cant load account showing blocked recharge operation
# neutral
# good evening ahmed mamou responded request private message thank checking messages 😊
# negative
# participate pleasure
# positive
# participate pleasure
# positive
# participate pleasure
# positive
# participate pleasure
# positive
# participate pleasure
# positive
# participate pleasure
# positive
# participate pleasure
# positive
# ...

# %%
comments = df['Comments']# Get the list of comments
positive_counts = []
negative_counts = []
neutral_counts = []
for comment in comments:
    comment_list = eval(comment)
    if len(comment_list) >= 2:
        positive_count = 0
        negative_count = 0
        neutral_count = 0
        for p in comment_list:
            text = p[3]
            print(text)
            if text == 'positive':
                text = 1
                positive_count += 1
            elif text == 'positive':
                text = -1
                negative_count += 1
            else:
                text = 0
                neutral_count += 1
                
            print(text)        
        print("Positive instances: ", positive_count)
        print("Negative instances: ", negative_count)
        print("neutral instances: ", neutral_count)
        positive_counts.append(positive_count)
        negative_counts.append(negative_count)
        neutral_counts.append(neutral_count)
    else:
        positive_counts.append(0)
        negative_counts.append(0)
        neutral_counts.append(0)
df['positive_count'] = positive_counts
df['negative_count'] = negative_counts
df['neutral_count'] = neutral_count
df.to_csv("data_with_scores.csv", index=False)
# Out:
# neutral
# 0
# neutral
# 0
# neutral
# 0
# neutral
# 0
# neutral
# 0
# neutral
# 0
# neutral
# 0
# neutral
# 0
# neutral
# 0
# neutral
# 0
# neutral
# 0
# positive
# 1
# neutral
# 0
# neutral
# 0
# positive
# 1
# Positive instances:  2
# Negative instances:  0
# neutral instances:  13
# positive
# 1
# positive
# 1
# positive
# 1
# neutral
# 0
# positive
# 1
# Positive instances:  4
# Negative instances:  0
# neutral instances:  1
# neutral
# 0
# negative
# 0
# positive
# 1
# positive
# 1
# positive
# 1
# positive
# 1
# positive
# 1
# positive
# 1
# positive
# 1
# positive
# 1
# positive
# 1
# neutral
# 0
# neutral
# 0
# positive
# 1
# neutral
# 0
# neutral
# 0
# neutral
# 0
# neutral
# 0
# neutral
# 0
# neutral
# 0
# neutral
# 0
# neutral
# 0
# neutral
# 0
# positive
# 1
# Positive instances:  11
# Negative instances:  0
# neutral instances:  13
# neutral
# 0
# positive
# 1
# positive
# 1
# negative
# 0
# positive
# 1
# negative
# 0
# neutral
# 0
# negative
# 0
# negative
# 0
# ...

# %%
import pandas as pd
import ast

# Assuming 'df' is the original DataFrame with a column named 'Comments'

# Parse the strings to convert them into lists
df['Comments'] = df['Comments']

# Extracting values from the nested list
commenter_list = []
comment_list = []
commenter_id_list = []

for item in df['Comments']:
    comment_lists = eval(item)
    for i in comment_lists:
        commenter_list.append(i[0])
        comment_list.append(i[1])
        commenter_id_list.append(i[2])
        
# Create DataFrame
df_new = pd.DataFrame({'Commenter': commenter_list, 'Comment': comment_list, 'Commenter ID': commenter_id_list})

# Print the DataFrame
print(df_new)
# Out:
#                     Commenter                                   Comment  \
# 0               Sleh Khmassi                       Game of word for you
# 1      Top fanربح محمود ساسي
# 2      Top fanربح محمود ساسي                       Game of word for you
# 3      Top fanربح محمود ساسي                       Game of word for you
# 4      Top fanربح محمود ساسي                       Game of word for you
# ...                       ...                                       ...
# 11273           Adel Soltani   So how much of Diveronis? Seven or seven
# 11274           Est Ali Hama                                      Seven
# 11275           Hmidi Lamine                    The vision is not clear
# 11276                  Ăz Ïž         The difference in Soum and Gigawat
# 11277               Walid Kr                                 7 for sure
#
#                                             Commenter ID
# 0      /sleh.khmassi?eav=Afb_1ifnIvVDBy56cDzZQEpiY1hZ...
# ...

# %%
# !pip install nltk
